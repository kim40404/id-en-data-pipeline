# %% [markdown]
# # Dataset Exploration and Cleaning
#
# In this notebook, we will load the raw ID-EN bilingual dataset and explore the dirty data.

# %%
import polars as pl

# Set display options for Polars
pl.Config.set_tbl_rows(10)

print("Environment ready!")
